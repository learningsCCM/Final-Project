# %% [markdown]
# # Final Project
# ### Divina M Arpino - 12/13/2023
#
# Objective:
# For my final project I selected to do data analysis for a fictitious client that is opening a small bookstore. The client would like recommendations on books he must absolutely invest in for his initial inventory.
#
# Dataset(s):
#     - Datasets being explored:
#         - https://www.kaggle.com/datasets/jealousleopard/goodreadsbooks/data
#         - https://www.kaggle.com/datasets/sootersaalu/amazon-top-50-bestselling-books-2009-2019/data

# %% [markdown]
# ## Read datasets from csv files

# %% [markdown]
# #### Initial structure update steps were needed when initial read of files showed some shifted columns. I went back to excel and fixed the column shifting there before re-importing
#
#  - I used Excel to address error that came up in the initial GoodReads file load ("ParserError: Error tokenizing data. C error: Expected 12 fields in line 3350, saw 13"):
# <i>The error was caused by data delimiter that shifter some columns to the right for four rows of data</i>
#   ![image.png](attachment:image.png)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#read csv files / store in working dataframes
data_goodreads = "input/books.csv"
data_amazon = "input/bestsellers with categories.csv"
df_goodreads = pd.read_csv(data_goodreads)
df_amazon = pd.read_csv(data_amazon)

# %% [markdown]
# ## Explore the Datasets

# %% [markdown]
# ### GoodReads dataset
# #### Check structure of the dataframe to familiarize with data and layout

# %%
df_goodreads.head(3)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
#
#                       authors  average_rating       isbn        isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  439785960  9.780440e+12
# 1  J.K. Rowling/Mary GrandPré            4.49  439358078  9.780440e+12
# 2                J.K. Rowling            4.42  439554896  9.780440e+12
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
#
#   publication_date        publisher
# 0          9/16/06  Scholastic Inc.
# 1           9/1/04  Scholastic Inc.
# 2          11/1/03       Scholastic

# %%
df_goodreads.tail()
# Out:
#        bookID                                             title  \
# 11122   45631  Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                       You Bright and Risen Angels
# 11124   45634                   The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                       Poor People
# 11126   45641                       Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 11122  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11123                                William T. Vollmann            4.08
# 11124                                William T. Vollmann            3.96
# 11125                                William T. Vollmann            3.72
# 11126                                         Mark Twain            3.91
#
#              isbn        isbn13 language_code    num_pages  ratings_count  \
# 11122  1560254416  9.781560e+12           eng          512            156
# 11123   140110879  9.780140e+12           eng          635            783
# 11124   140131965  9.780140e+12           eng          415            820
# 11125    60878827  9.780060e+12           eng          434            769
# 11126  8497646983  9.788500e+12           spa          272            113
#
#        text_reviews_count publication_date      publisher
# 11122                  20         12/21/04  Da Capo Press
# 11123                  56          12/1/88  Penguin Books
# 11124                  95           8/1/93  Penguin Books
# 11125                 139          2/27/07           Ecco
# 11126                  12          5/28/06  Edimat Libros

# %%
df_goodreads.shape
# Out:
# (11127, 12)

# %%
df_goodreads.sample()
# Out:
#       bookID                                              title  \
# 4467   16111  A Dance to the Music of Time: 4th Movement (A ...
#
#              authors  average_rating       isbn        isbn13 language_code  \
# 4467  Anthony Powell            4.22  226677184  9.780230e+12           eng
#
#         num_pages  ratings_count  text_reviews_count publication_date  \
# 4467          793           1145                  77          5/31/95
#
#                         publisher
# 4467  University of Chicago Press

# %%
#no null values found on the dataset
df_goodreads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11127 non-null  int64
#  1   title               11127 non-null  object
#  2   authors             11127 non-null  object
#  3   average_rating      11127 non-null  float64
#  4   isbn                11127 non-null  object
#  5   isbn13              11127 non-null  float64
#  6   language_code       11127 non-null  object
#  7     num_pages         11127 non-null  int64
#  8   ratings_count       11127 non-null  int64
#  9   text_reviews_count  11127 non-null  int64
#  10  publication_date    11127 non-null  object
#  11  publisher           11127 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 1.0+ MB

# %%
#columns will need some renaming, num_pages has extra spaces. Some columns will not be needed
df_goodreads.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', '  num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %% [markdown]
# ### Amazon dataset
# #### Check structure of dataframe to familiarize with data and layout

# %%
df_amazon.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df_amazon.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
df_amazon.shape
# Out:
# (550, 7)

# %%
df_amazon.sample()
# Out:
#                     Name  Author  User Rating  Reviews  Price  Year  \
# 308  StrengthsFinder 2.0  Gallup          4.0     5069     17  2013
#
#            Genre
# 308  Non Fiction

# %%
#no null values found on the dataset
df_amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
# Will need to rename User Rating to remove space
df_amazon.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Amazon Dataset

# %% [markdown]
# #### There are no null values in this dataset. No cleaning in this area is necessary

# %%
df_amazon.isnull().sum()
# Out:
# Name          0
# Author        0
# UserRating    0
# Reviews       0
# Price         0
# Year          0
# Genre         0
# dtype: int64

# %% [markdown]
# #### Rename User Rating column to remove space

# %%
df_amazon.rename(
    columns=({ 'User Rating': 'UserRating'}), 
    inplace=True,
)
df_amazon.columns
# Out:
# Index(['Name', 'Author', 'UserRating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
# Checking to make sure each year lists the Top 50
df_amazon['Year'].value_counts()
# Out:
# Year
# 2016    50
# 2011    50
# 2018    50
# 2017    50
# 2019    50
# 2014    50
# 2010    50
# 2009    50
# 2015    50
# 2013    50
# 2012    50
# Name: count, dtype: int64

# %% [markdown]
# ### GoodReads Dataset

# %% [markdown]
# #### There are no null values in this dataset. No cleaning in this area is necessary

# %%
df_goodreads.isnull().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
#   num_pages           0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# dtype: int64

# %% [markdown]
# #### Remove extra spaces in goodreads dataset

# %%
df_goodreads.columns.str.lstrip()
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', 'num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %% [markdown]
# #### Drop non-needed data
# For simplicity and to avoid duplication of titles, I am dropping all titles that are not in ENG or EN-US. The counts in the other languages are also smaller and likely not part ot the Amazon dataset either, so it makes most sense to drop them at this point

# %%
#Look at the language codes in the dataset
df_goodreads['language_code'].value_counts()
# Out:
# language_code
# eng      8911
# en-US    1409
# spa       218
# en-GB     214
# fre       144
# ger        99
# jpn        46
# mul        19
# zho        14
# grc        11
# por        10
# en-CA       7
# ita         5
# enm         3
# lat         3
# swe         2
# rus         2
# srp         1
# nl          1
# msa         1
# glg         1
# wel         1
# ara         1
# nor         1
# tur         1
# gla         1
# ale         1
# Name: count, dtype: int64

# %%
# Languages(chatGPT insight on how to complete - 'how to drop specific rows of data based on values in column')
languages = ['eng', 'en-US']

# Drop all other rows 
df_goodreads = df_goodreads[df_goodreads['language_code'].isin(languages)]
df_goodreads['language_code'].value_counts()
# Out:
# language_code
# eng      8911
# en-US    1409
# Name: count, dtype: int64

# %% [markdown]
# #### Drop non-needed columns
# At this point I also don't care for the 'bookID', isbn', 'isbn13', 'language_code', or 'publisher', so I am going to drop those columns altogether (chatGPT insight on this one 'how to drop columns from a dataframe using column name')

# %%
# Columns to drop
gr_drop_cols = ['bookID', 'isbn', 'isbn13', 'language_code', 'publisher']

# Drop the specified columns
df_goodreads = df_goodreads.drop(columns=gr_drop_cols)
df_goodreads.head(5)
# Out:
#                                                title  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating  num_pages  ratings_count  \
# 0  J.K. Rowling/Mary GrandPré            4.57        652        2095690
# 1  J.K. Rowling/Mary GrandPré            4.49        870        2153167
# 2                J.K. Rowling            4.42        352           6333
# 3  J.K. Rowling/Mary GrandPré            4.56        435        2339585
# 4  J.K. Rowling/Mary GrandPré            4.78       2690          41428
#
#    text_reviews_count publication_date
# 0               27591          9/16/06
# 1               29221           9/1/04
# 2                 244          11/1/03
# 3               36325           5/1/04
# 4                 164          9/13/04

# %% [markdown]
# #### Restyle column names
# To match the Amazon date styles, I am changing the publication date to a year.
# Note: unline the amazon top 50, this date does not relate to a bestselling year, it is instead the year of publication. So although it can't be used to compare with the amazon dataset, it will be useful to have it converted to a year for graphing purposes (google search helped with the command here)
#
# I am also renaming the columns to be a closer match to the amazon dataset as it will make it easier to use the same code for both datasets where needed.

# %%
# Convert 'PublicationDate' to datetime format
df_goodreads['publication_date'] = pd.to_datetime(df_goodreads['publication_date'], errors='coerce')

# Extract the four-digit year
df_goodreads['Year'] = df_goodreads['publication_date'].dt.year.astype('Int64')

# Drop the original 'PublicationDate' column if needed
df_goodreads.drop(columns=['publication_date'], inplace=True)
df_goodreads.head(5)
# Out:
# /var/folders/jn/b7xrp7ts1n3fmnzk1xldvd4r0000gn/T/ipykernel_52535/4023865782.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_goodreads['publication_date'] = pd.to_datetime(df_goodreads['publication_date'], errors='coerce')
#                                                title  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating  num_pages  ratings_count  \
# 0  J.K. Rowling/Mary GrandPré            4.57        652        2095690
# 1  J.K. Rowling/Mary GrandPré            4.49        870        2153167
# 2                J.K. Rowling            4.42        352           6333
# 3  J.K. Rowling/Mary GrandPré            4.56        435        2339585
# 4  J.K. Rowling/Mary GrandPré            4.78       2690          41428
#
#    text_reviews_count  Year
# 0               27591  2006
# 1               29221  2004
# 2                 244  2003
# 3               36325  2004
# 4                 164  2004

# %%
# Rename multiple columns
df_goodreads = df_goodreads.rename(columns={'title': 'Name',
                   'authors': 'Author',
                   'average_rating': 'UserRating',
                   'num_pages': 'Pages',
                   'ratings_count': 'RatingsCount',
                   'text_reviews_count': 'Reviews'})
df_goodreads.head(5)
# Out:
#                                                 Name  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        Author  UserRating  Pages  RatingsCount  Reviews  Year
# 0  J.K. Rowling/Mary GrandPré        4.57    652       2095690    27591  2006
# 1  J.K. Rowling/Mary GrandPré        4.49    870       2153167    29221  2004
# 2                J.K. Rowling        4.42    352          6333      244  2003
# 3  J.K. Rowling/Mary GrandPré        4.56    435       2339585    36325  2004
# 4  J.K. Rowling/Mary GrandPré        4.78   2690         41428      164  2004

# %% [markdown]
# #### Cleanup notes
# - I checked for null values and didn't find any
# - I renamed User Rating above to remove space, and removed spaces in the goodreads num_pages
# - As I began analyzing the data I added cleaning actions to the goodreads dataset. I dropped extra data that is not needed, dropped extra columns, and renamed columns to be more closely named to those of the Amazon dataset

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# #### What are the top 5 books in fiction and non-fiction genre based on highest number or rating and user reviews for each year?
# For this answer we look at the Amazon dataset because goodreads does not have a genre breakdown. A comparision of the Fiction and NonFiction genres for their average user rating and the sum of the genre reviews. This shows that Fiction books are getting slightly better average ratings,
# and are reviewed by more people
#
# - Analyzing Genre (Amazon) - Ratings/Reviews per genre
#     - First I compared the Fiction and NonFiction genres for their average user rating and the sum of the genre reviews. This shows that Fiction books are getting slightly better average ratings, and are reviewed by more people
#
# - Analyzing Genre (Amazon) - Top 5 based on UserRatings - grouped by year
#
#
# - Analyzing Genre (Amazon) - Top 5 based on Reviews - accross years
#
#
# Note: I used ChatGPT to help with aggregating multiple columns in result and also for proper use of applying with lambda

# %%
# Analyzing Genre (Amazon) - Ratings/Reviews per genre
df_amazon.groupby('Genre').agg({'UserRating': 'mean', 'Reviews': 'sum'}).reset_index()
# Out:
#          Genre  UserRating  Reviews
# 0      Fiction    4.648333  3764110
# 1  Non Fiction    4.595161  2810195

# %%
# Analyzing Genre (Amazon) - Ratings/Reviews per genre - counts
df_amazon.groupby('Genre').Name.count().reset_index()
# Out:
#          Genre  Name
# 0      Fiction   240
# 1  Non Fiction   310

# %%
# Analyzing Genre - Here we plot the count of books of each genre from the previous cell
sns.countplot(
    data=df_amazon, x =df_amazon['Genre']
)
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
# Analyzing Genre (Amazon) - Top 3 based on UserRatings - grouped by year
# **** changed to top 3 instead of top5 here for purposes of the presenation on this assignment ***
amz_top5year_ratings = df_amazon.groupby(df_amazon['Year']).apply(lambda x: x.nlargest(3, 'UserRating')).reset_index(drop=True)
amz_top5year_ratings.head(10)
# Out:
#                                                 Name                Author  \
# 0      Diary of a Wimpy Kid: The Last Straw (Book 3)           Jeff Kinney
# 1  Dog Days (Diary of a Wimpy Kid, Book 4) (Volum...           Jeff Kinney
# 2                  Have a Little Faith: A True Story           Mitch Albom
# 3  Percy Jackson and the Olympians Paperback Boxe...          Rick Riordan
# 4                                           The Help      Kathryn Stockett
# 5  The Last Olympian (Percy Jackson and the Olymp...          Rick Riordan
# 6  Jesus Calling: Enjoying Peace in His Presence ...           Sarah Young
# 7         Cabin Fever (Diary of a Wimpy Kid, Book 6)           Jeff Kinney
# 8                               Go the F**k to Sleep         Adam Mansbach
# 9  Goodnight, Goodnight Construction Site (Hardco...  Sherri Duskey Rinker
#
#    UserRating  Reviews  Price  Year        Genre
# 0         4.8     3837     15  2009      Fiction
# 1         4.8     3181     12  2009      Fiction
# 2         4.8     1930      4  2009  Non Fiction
# 3         4.8      548      2  2010      Fiction
# 4         4.8    13871      6  2010      Fiction
# 5         4.8     4628      7  2010      Fiction
# 6         4.9    19576      8  2011  Non Fiction
# 7         4.8     4505      0  2011      Fiction
# 8         4.8     9568      9  2011      Fiction
# 9         4.9     7038      7  2012      Fiction

# %%
# Sort the DataFrame by UserRating to graph it in that order
amz_top5year_ratings = amz_top5year_ratings.sort_values(by='UserRating', ascending=False)

# Create a grouped bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='UserRating', y='Name', hue='Genre', data=amz_top5year_ratings, palette='viridis')
plt.title('Top-Rated Books by Genre for Each Year')
plt.xlabel('User Rating')
plt.ylabel('Name')
plt.legend(title='Genre')
plt.show()

# %%
# Analyzing Genre (Amazon) - Top 5 based on Reviews - accross years
amz_top5year_reviews = df_amazon.groupby(df_amazon['Year']).apply(lambda x: x.nlargest(5, 'Reviews')).reset_index(drop=True)
amz_top5year_reviews.head(10)
# Out:
#                                                 Name             Author  \
# 0        The Shack: Where Tragedy Confronts Eternity   William P. Young
# 1                                           The Help   Kathryn Stockett
# 2               Twilight (The Twilight Saga, Book 1)    Stephenie Meyer
# 3  The Girl with the Dragon Tattoo (Millennium Se...      Stieg Larsson
# 4                     Outliers: The Story of Success   Malcolm Gladwell
# 5                                   The Hunger Games    Suzanne Collins
# 6  Unbroken: A World War II Story of Survival, Re...  Laura Hillenbrand
# 7                      Mockingjay (The Hunger Games)    Suzanne Collins
# 8                   Catching Fire (The Hunger Games)    Suzanne Collins
# 9                                           The Help   Kathryn Stockett
#
#    UserRating  Reviews  Price  Year        Genre
# 0         4.6    19720      8  2009      Fiction
# 1         4.8    13871      6  2009      Fiction
# 2         4.7    11676      9  2009      Fiction
# 3         4.4    10559      2  2009      Fiction
# 4         4.6    10426     20  2009  Non Fiction
# 5         4.7    32122     14  2010      Fiction
# 6         4.8    29673     16  2010  Non Fiction
# 7         4.5    26741      8  2010      Fiction
# 8         4.7    22614     11  2010      Fiction
# 9         4.8    13871      6  2010      Fiction

# %%
#Graph the Fiction vs. Non-Fiction numbers for each year according to user rating sum
pivot_df = df_amazon.pivot_table(index='Year', columns='Genre', values='UserRating', aggfunc='sum')
#pivot_df

pivot_df.plot(kind='bar', stacked=True, cmap='tab20c', figsize=(10, 6))


# Set labels and title
plt.xlabel('Year')
plt.ylabel('User Rating')
plt.title('Fiction vs. Non-Fiction Popularity per Year')

# Show the plot
plt.legend(title='Genre')
plt.show()

# %% [markdown]
# #### What books make the rankings over several years?
# In this section I grouped the books in the amazon top 50 dataframe (previous created by ratings) and graphed (with several iterations of help from chatGPT) to display a per year chart

# %%
#Graph books per year using the ratings df

# Group books by year
grouped_books = amz_top5year_ratings.groupby('Year')['Name'].apply(list)
grouped_books

# Plotting the scatter plot
plt.figure(figsize=(10, 8))
for year, books in grouped_books.items():
    plt.scatter([year] * len(books), books, label=str(year), alpha=0.7)

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Book Name')
plt.title('Books per Year')

# Show the plot
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.show()

# %%
#Graph books per year using the reviews df

# Group books by year
grouped_books = amz_top5year_reviews.groupby('Year')['Name'].apply(list)
grouped_books

# Plotting the scatter plot
plt.figure(figsize=(10, 8))
for year, books in grouped_books.items():
    plt.scatter([year] * len(books), books, label=str(year), alpha=0.7)

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Book Name')
plt.title('Books per Year')

# Show the plot
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.show()

# %% [markdown]
# #### Does cost of book influence their popularity?
# For this question we look at only the Amazon data set. The goodreads data set does not include cost.
#
# We learn that there are 'popular' books on the list that are in the top of expensive items. It appears that these books are more for necessity than for enjoyment (textbooks, exam prep, etc.). This leads to the question of books that are most popular and their cost based on user ratings as opposed to just sales.

# %%
# List top 10 most expensive book titles. From the results here it seems we have to explore whether the books
   # making top lists are based on popularity, or based on need. Four of these top 10 books are study guides
   # or textbooks.
   # Note the second item is a boxed set and not a book

df_amazon.groupby("Name")["Price"].mean().sort_values(ascending=False).head(10)
# Out:
# Name
# Diagnostic and Statistical Manual of Mental Disorders, 5th Edition: DSM-5            105.0
# The Twilight Saga Collection                                                          82.0
# Hamilton: The Revolution                                                              54.0
# The Book of Basketball: The NBA According to The Sports Guy                           53.0
# Harry Potter Paperback Box Set (Books 1-7)                                            52.0
# Publication Manual of the American Psychological Association, 6th Edition             46.0
# Watchmen                                                                              42.0
# The Official SAT Study Guide                                                          40.0
# The Alchemist                                                                         39.0
# The Official SAT Study Guide, 2016 Edition (Official Study Guide for the New Sat)     36.0
# Name: Price, dtype: float64

# %%
# Here we use a seaborn plot to map the UserRatings against the book Price (courtersy of ChatGPT)
# We can see that most of the books that have highest user ratings fall in the lower price range, 
  # however, the expensive 'need' books are still receiving reasonably high reviews, so people are not 
  # totally disatisfied with them
sns.lmplot(y='UserRating',x='Price',data=df_amazon)
plt.ylabel('Ratings')
plt.xlabel('Price');
# Out:
# /Users/darpino/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Show titles with highest occurrence counts accross all years
amz_name_counts = df_amazon.groupby('Genre').apply(lambda x: x['Name'].value_counts().head(5))

amz_name_counts
# Out:
# Genre        Name
# Fiction      Oh, the Places You'll Go!                                                             8
#              The Very Hungry Caterpillar                                                           7
#              Giraffes Can't Dance                                                                  5
#              Wonder                                                                                5
#              To Kill a Mockingbird                                                                 5
# Non Fiction  Publication Manual of the American Psychological Association, 6th Edition            10
#              StrengthsFinder 2.0                                                                   9
#              The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change          7
#              Jesus Calling: Enjoying Peace in His Presence (with Scripture References)             6
#              The Four Agreements: A Practical Guide to Personal Freedom (A Toltec Wisdom Book)     6
# Name: count, dtype: int64

# %% [markdown]
# #### Authors with the highest counts of books in top 50 over the years

# %%
amz_popular_authors = df_amazon.groupby('Author')['Author'].agg(['count']).sort_values(by='count',ascending=False).head(10)
amz_popular_authors.reset_index(inplace=True)

amz_popular_authors
# Out:
#                                Author  count
# 0                         Jeff Kinney     12
# 1                        Gary Chapman     11
# 2                     Suzanne Collins     11
# 3                        Rick Riordan     11
# 4  American Psychological Association     10
# 5                              Gallup      9
# 6                           Dr. Seuss      9
# 7                         Rob Elliott      8
# 8                          Eric Carle      7
# 9                       Bill O'Reilly      7

# %%
# Amazon - Create a bar chart graphing the counts per author
plt.figure(figsize=(10, 6))
plt.bar(amz_popular_authors['Author'], amz_popular_authors['count'], color='skyblue')

# Set labels and title
plt.xlabel('Author')
plt.ylabel('Count')
plt.title('Book Count by Author')

# Show the bar chart
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better visualization
plt.show()

# %%
#Goodreads - Authors with highest book counts

gr_popular_authors = df_goodreads.groupby('Author')['Author'].agg(['count']).sort_values(by='count',ascending=False).head(10)
gr_popular_authors.reset_index(inplace=True)

gr_popular_authors
# Out:
#                         Author  count
# 0               P.G. Wodehouse     40
# 1                 Stephen King     37
# 2              Agatha Christie     33
# 3             Orson Scott Card     32
# 4                Piers Anthony     29
# 5                 Sandra Brown     28
# 6                 Dick Francis     28
# 7              Mercedes Lackey     27
# 8             Rumiko Takahashi     24
# 9  Margaret Weis/Tracy Hickman     23

# %%
# Goodreads - Create a bar chart graphing the counts per author
plt.figure(figsize=(10, 6))
plt.bar(gr_popular_authors['Author'], gr_popular_authors['count'], color='skyblue')

# Set labels and title
plt.xlabel('Author')
plt.ylabel('Count')
plt.title('Book Count by Author')

# Show the bar chart
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better visualization
plt.show()

# %% [markdown]
# #### Books with highest ratings and reviews

# %%
#Amazon books with highest ratings (I used chatGPT to help with selecting unique 10)
df_amazon[df_amazon.UserRating == 4.9]['Name'].unique()[:10]
# Out:
# array(['Brown Bear, Brown Bear, What Do You See?',
#        'Dog Man and Cat Kid: From the Creator of Captain Underpants (Dog Man #4)',
#        'Dog Man: A Tale of Two Kitties: From the Creator of Captain Underpants (Dog Man #3)',
#        'Dog Man: Brawl of the Wild: From the Creator of Captain Underpants (Dog Man #6)',
#        'Dog Man: Fetch-22: From the Creator of Captain Underpants (Dog Man #8)',
#        'Dog Man: For Whom the Ball Rolls: From the Creator of Captain Underpants (Dog Man #7)',
#        'Dog Man: Lord of the Fleas: From the Creator of Captain Underpants (Dog Man #5)',
#        'Goodnight, Goodnight Construction Site (Hardcover Books for Toddlers, Preschool Books for Kids)',
#        'Hamilton: The Revolution',
#        'Harry Potter and the Chamber of Secrets: The Illustrated Edition (Harry Potter, Book 2)'],
#       dtype=object)

# %%
#goodreads
df_goodreads[df_goodreads['UserRating'] >= 4.9].sort_values(by='UserRating', ascending=False)[['Name', 'UserRating']].reset_index(drop=True).head(20)
# Out:
#                                                  Name  UserRating
# 0                   Willem de Kooning: Late Paintings         5.0
# 1   Colossians and Philemon: A Critical and Exeget...         5.0
# 2   His Princess Devotional: A Royal Encounter Wit...         5.0
# 3   The American Campaign: U.S. Presidential Campa...         5.0
# 4       The Irish Anatomist: A Study of Flann O'Brien         5.0
# 5                  Tyrannosaurus Wrecks (Stanley  #1)         5.0
# 6   Oliver Wendell Holmes in Paris: Medicine  Theo...         5.0
# 7        Fanning the Flame: Bible  Cross  and Mission         5.0
# 8                         The New Big Book of America         5.0
# 9                           Taxation of Mineral Rents         5.0
# 10                                Winchester Shotguns         5.0
# 11  Literature Circle Guide: Bridge to Terabithia:...         5.0
# 12  The Goon Show  Volume 11: He's Fallen in the W...         5.0
# 13  The Goon Show  Volume 4: My Knees Have Fallen ...         5.0
# 14  The Complete Theory Fun Factory: Music Theory ...         5.0
# 15  Bulgakov's the Master and Margarita: The Text ...         5.0
# 16  The Diamond Color Meditation: Color Pathway to...         5.0
# 17  Zone of the Enders: The 2nd Runner Official St...         5.0
# 18  Middlesex Borough (Images of America: New Jersey)         5.0
# 19         Bill Gates: Computer Legend (Famous Lives)         5.0

# %%
#df_amazon[['Name','Genre','Reviews']].sort_values(by='Reviews',ascending=False).head(10)

amz_top5year_reviews1 = df_amazon[['Name','Genre','Year','Reviews']].groupby(df_amazon['Year']).apply(lambda x: x.nlargest(5, 'Reviews')).reset_index(drop=True)
amz_top5year_reviews1.head(20)
# Out:
#                                                  Name        Genre  Year  \
# 0         The Shack: Where Tragedy Confronts Eternity      Fiction  2009
# 1                                            The Help      Fiction  2009
# 2                Twilight (The Twilight Saga, Book 1)      Fiction  2009
# 3   The Girl with the Dragon Tattoo (Millennium Se...      Fiction  2009
# 4                      Outliers: The Story of Success  Non Fiction  2009
# 5                                    The Hunger Games      Fiction  2010
# 6   Unbroken: A World War II Story of Survival, Re...  Non Fiction  2010
# 7                       Mockingjay (The Hunger Games)      Fiction  2010
# 8                    Catching Fire (The Hunger Games)      Fiction  2010
# 9                                            The Help      Fiction  2010
# 10                          The Hunger Games (Book 1)      Fiction  2011
# 11  Unbroken: A World War II Story of Survival, Re...  Non Fiction  2011
# 12                      Mockingjay (The Hunger Games)      Fiction  2011
# 13                   Catching Fire (The Hunger Games)      Fiction  2011
# 14  Jesus Calling: Enjoying Peace in His Presence ...  Non Fiction  2011
# 15                                          Gone Girl      Fiction  2012
# 16                             The Fault in Our Stars      Fiction  2012
# 17  Fifty Shades of Grey: Book One of the Fifty Sh...      Fiction  2012
# 18                          The Hunger Games (Book 1)      Fiction  2012
# 19  Unbroken: A World War II Story of Survival, Re...  Non Fiction  2012
#
#     Reviews
# 0     19720
# 1     13871
# 2     11676
# 3     10559
# 4     10426
# 5     32122
# 6     29673
# 7     26741
# 8     22614
# 9     13871
# 10    32122
# 11    29673
# 12    26741
# 13    22614
# 14    19576
# 15    57271
# 16    50482
# 17    47265
# 18    32122
# 19    29673

# %%
#goodreads
gr_top_reviews = df_goodreads[['Name','Year','UserRating', 'RatingsCount', 'Reviews']].groupby(df_goodreads['Year']).apply(lambda x: x.nlargest(5, 'RatingsCount')).reset_index(drop=True)
gr_top_reviews.head(20)
# Out:
#                                                  Name  Year  UserRating  \
# 0                                   Moonraker's Bride  1973        4.31
# 1                                       The Pound Era  1973        4.37
# 2                   Battle for the Planet of the Apes  1973        3.66
# 3   The Princess Bride: S. Morgenstern's Classic T...  1973        4.26
# 4                              Li Po and Tu Fu: Poems  1973        4.14
# 5                                       Turtle Island  1974        4.09
# 6                                Saint Thomas Aquinas  1974        4.14
# 7                         Virginia Woolf: A Biography  1974        4.17
# 8                             The Only Dance There Is  1974        4.24
# 9                                 Stone Age Economics  1974        3.90
# 10  The Power Broker: Robert Moses and the Fall of...  1975        4.51
# 11  The Valley of Vision: A Collection of Puritan ...  1975        4.54
# 12           Existentialism from Dostoevsky to Sartre  1975        4.08
# 13                                               Love  1975        3.71
# 14                                       'Salem's Lot  1975        4.02
# 15                    Hegel's Phenomenology of Spirit  1976        3.93
# 16                               Essays and Aphorisms  1976        4.17
# 17  West from Home: Letters of Laura Ingalls Wilde...  1976        3.84
# 18                                     A Severed Head  1976        3.73
# 19                                              Flush  1976        3.83
#
#     RatingsCount  Reviews
# 0           2281      302
# 1            614       29
# 2            461       10
# 3            460       73
# 4            389       28
# 5           3809      105
# 6           2987      175
# 7           2583       66
# 8            713       30
# 9            281       26
# 10         11208     1237
# 11          9476      247
# 12          5011       88
# 13          1083       51
# 14          1039      130
# 15         13920      248
# 16          6222      169
# 17          3926      119
# 18          3682      319
# 19          3567      336

# %% [markdown]
# #### Look into impact of ratings, rating counts, review counts, etc.

# %%
#Distribution of ratings Amazon to see how the ratings impact a book being on 50 bestseller
sns.histplot(data=df_amazon.UserRating,bins=10)
plt.xlabel("User Rating");

# %%
#Distribution of ratings Goodreads - since this is not top50, but all books, the distribution is broader
sns.histplot(data=df_goodreads.UserRating,bins=10)
plt.xlabel("UserRating");

# %%
#Amazon analysis of user ratings and review counts

# Scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='UserRating', y='Reviews', data=df_amazon, palette='viridis', s=100, alpha=0.7)

# Set labels and title
plt.xlabel('Rating')
plt.ylabel('Review Count')
plt.title('Book Ratings vs Review Counts')

# Show the plot
plt.show()
# Out:
# /var/folders/jn/b7xrp7ts1n3fmnzk1xldvd4r0000gn/T/ipykernel_52535/3181213372.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='UserRating', y='Reviews', data=df_amazon, palette='viridis', s=100, alpha=0.7)

# %%
#Goodreads analysis of user ratings and review counts

# Scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='UserRating', y='Reviews', data=df_goodreads, palette='viridis', s=100, alpha=0.7)

# Set labels and title
plt.xlabel('Rating')
plt.ylabel('Review Count')
plt.title('Book Ratings vs Review Counts')

# Show the plot
plt.show()
# Out:
# /var/folders/jn/b7xrp7ts1n3fmnzk1xldvd4r0000gn/T/ipykernel_52535/3549985124.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='UserRating', y='Reviews', data=df_goodreads, palette='viridis', s=100, alpha=0.7)

# %%
#Goodreads - but UserRating vs. RatingsCount

# Scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='UserRating', y='RatingsCount', data=df_goodreads, palette='viridis', s=100, alpha=0.7)

# Set labels and title
plt.xlabel('Rating')
plt.ylabel('Ratings Count')
plt.title('Book Ratings vs Rating Counts')

# Show the plot
plt.show()
# Out:
# /var/folders/jn/b7xrp7ts1n3fmnzk1xldvd4r0000gn/T/ipykernel_52535/1799085977.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='UserRating', y='RatingsCount', data=df_goodreads, palette='viridis', s=100, alpha=0.7)

# %%
# Amazon - taking a look at what those top 25 reviewed books are
amz_topReviewCounts = df_amazon[df_amazon['Reviews'] > 6000][['Name', 'Reviews','UserRating']].sort_values(by='Reviews',ascending=False).drop_duplicates().reset_index(drop=True).head(25)
amz_topReviewCounts
# Out:
#                                                  Name  Reviews  UserRating
# 0                             Where the Crawdads Sing    87841         4.8
# 1                               The Girl on the Train    79446         4.1
# 2                                            Becoming    61133         4.8
# 3                                           Gone Girl    57271         4.0
# 4                              The Fault in Our Stars    50482         4.7
# 5                            The Nightingale: A Novel    49288         4.8
# 6   Fifty Shades of Grey: Book One of the Fifty Sh...    47265         3.8
# 7                                         The Martian    39459         4.7
# 8                         All the Light We Cannot See    36348         4.6
# 9                                       The Alchemist    35799         4.7
# 10  The Goldfinch: A Novel (Pulitzer Prize for Fic...    33844         3.9
# 11                          The Hunger Games (Book 1)    32122         4.7
# 12                                   The Hunger Games    32122         4.7
# 13                                   The Wonky Donkey    30183         4.8
# 14  Unbroken: A World War II Story of Survival, Re...    29673         4.8
# 15                                            Inferno    29651         4.1
# 16                                The Handmaid's Tale    29442         4.3
# 17                                 Educated: A Memoir    28729         4.7
# 18                                 The Silent Patient    27536         4.5
# 19                                          Divergent    27098         4.6
# 20                      Mockingjay (The Hunger Games)    26741         4.5
# 21  The Subtle Art of Not Giving a F*ck: A Counter...    26490         4.6
# 22                              To Kill a Mockingbird    26234         4.8
# 23                            Little Fires Everywhere    25706         4.5
# 24  Grey: Fifty Shades of Grey as Told by Christia...    25624         4.4

# %%
# Amazon - graphinc the above output

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(amz_topReviewCounts['Name'], amz_topReviewCounts['Reviews'], color='skyblue')

# Set labels and title
plt.xlabel('Name')
plt.ylabel('Reviews')
plt.title('Book Reviews by Author')

# Show the bar chart
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better visualization
plt.show()

# %%
# Goodreads - taking a look at what those top most rated books are
gr_topReviewCounts = df_goodreads[df_goodreads['RatingsCount'] > 2000000][['Name', 'Reviews','UserRating','RatingsCount']].sort_values(by='Reviews',ascending=False).drop_duplicates().reset_index(drop=True).head(25)
gr_topReviewCounts
# Out:
#                                                  Name  Reviews  UserRating  \
# 0                             Twilight (Twilight  #1)    94265        3.59
# 1                              The Catcher in the Rye    43499        3.80
# 2   Harry Potter and the Prisoner of Azkaban (Harr...    36325        4.56
# 3   Harry Potter and the Chamber of Secrets (Harry...    34692        4.42
# 4                 The Hobbit  or There and Back Again    32871        4.27
# 5                                         Animal Farm    29677        3.93
# 6   Harry Potter and the Order of the Phoenix (Har...    29221        4.49
# 7   Harry Potter and the Half-Blood Prince (Harry ...    27591        4.57
# 8                                   Lord of the Flies    26199        3.68
# 9                Angels & Demons (Robert Langdon  #1)    21303        3.89
# 10  The Fellowship of the Ring (The Lord of the Ri...    13670        4.36
#
#     RatingsCount
# 0        4597666
# 1        2457092
# 2        2339585
# 3        2293963
# 4        2530894
# 5        2111750
# 6        2153167
# 7        2095690
# 8        2036679
# 9        2418736
# 10       2128944

# %%
# Goodreads - taking a look at what those top most reviewed books are
gr_topReviewCounts = df_goodreads[df_goodreads['Reviews'] > 35000][['Name', 'Reviews','UserRating','RatingsCount']].sort_values(by='Reviews',ascending=False).drop_duplicates().reset_index(drop=True).head(10)
gr_topReviewCounts
# Out:
#                                                 Name  Reviews  UserRating  \
# 0                            Twilight (Twilight  #1)    94265        3.59
# 1                                     The Book Thief    86881        4.37
# 2                          The Giver (The Giver  #1)    56604        4.13
# 3                                      The Alchemist    55843        3.86
# 4                                Water for Elephants    52759        4.09
# 5  The Lightning Thief (Percy Jackson and the Oly...    47951        4.25
# 6                                    Eat  Pray  Love    47620        3.55
# 7                                   The Glass Castle    46176        4.27
# 8                             The Catcher in the Rye    43499        3.80
# 9  Harry Potter and the Prisoner of Azkaban (Harr...    36325        4.56
#
#    RatingsCount
# 0       4597666
# 1       1516367
# 2       1585589
# 3       1631221
# 4       1260027
# 5       1766725
# 6       1362264
# 7        808656
# 8       2457092
# 9       2339585

# %%
#Goodreads - graphing the output (reviews by author)

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(gr_topReviewCounts['Name'], gr_topReviewCounts['Reviews'], color='skyblue')

# Set labels and title
plt.xlabel('Name')
plt.ylabel('Reviews')
plt.title('Book Reviews by Author')

# Show the bar chart
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better visualization
plt.show()

# %%
#Goodreads - graphing the output (reating counts by author)
gr_topRatingCounts = gr_topReviewCounts.sort_values(by='RatingsCount', ascending=False).reset_index(drop=True).head(25)
# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(gr_topRatingCounts['Name'], gr_topRatingCounts['RatingsCount'], color='skyblue')

# Set labels and title
plt.xlabel('Name')
plt.ylabel('Ratings Counts')
plt.title('Book Ratings by Author')

# Show the bar chart
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better visualization
plt.show()

# %%
#Goodreads - graphing the output (ratings by author)
gr_topRatings = gr_topReviewCounts.sort_values(by='UserRating', ascending=False).reset_index(drop=True).head(25)
# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(gr_topRatings['Name'], gr_topRatings['UserRating'], color='skyblue')

# Set labels and title
plt.xlabel('Name')
plt.ylabel('User Rating')
plt.title('Book Ratings by Author')

# Show the bar chart
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better visualization
plt.show()

# %%
# Display the top ten books by rating counts and review counts d
gr_reviews_rating = pd.concat([gr_topRatingCounts['Name'], gr_topReviewCounts['Name']], axis=1)
gr_reviews_rating
# Out:
#                                                 Name  \
# 0                            Twilight (Twilight  #1)
# 1                             The Catcher in the Rye
# 2  Harry Potter and the Prisoner of Azkaban (Harr...
# 3  The Lightning Thief (Percy Jackson and the Oly...
# 4                                      The Alchemist
# 5                          The Giver (The Giver  #1)
# 6                                     The Book Thief
# 7                                    Eat  Pray  Love
# 8                                Water for Elephants
# 9                                   The Glass Castle
#
#                                                 Name
# 0                            Twilight (Twilight  #1)
# 1                                     The Book Thief
# 2                          The Giver (The Giver  #1)
# 3                                      The Alchemist
# 4                                Water for Elephants
# 5  The Lightning Thief (Percy Jackson and the Oly...
# 6                                    Eat  Pray  Love
# 7                                   The Glass Castle
# 8                             The Catcher in the Rye
# 9  Harry Potter and the Prisoner of Azkaban (Harr...

# %%
#goodreads books with a rating = 4.3 and highest counts of User Rating counts (sort by UserRating)

df_test = df_goodreads[
    (df_goodreads['RatingsCount'] > 250000) & (df_goodreads['UserRating'] >= 4.3)
][['Name', 'Reviews', 'UserRating', 'RatingsCount']].sort_values(
    by='UserRating', ascending=False
).drop_duplicates().reset_index(drop=True).head(25)

df_test
#gr_topRatingsCounts = df_goodreads[df_goodreads['RatingsCount'] > 2000000][['Name', 'Reviews','UserRating','RatingsCount']].sort_values(by='RatingsCount',ascending=False).drop_duplicates().reset_index(drop=True).head(25)
#gr_topRatingsCounts
# Out:
#                                                  Name  Reviews  UserRating  \
# 0   Harry Potter and the Half-Blood Prince (Harry ...    27591        4.57
# 1   Harry Potter and the Prisoner of Azkaban (Harr...    36325        4.56
# 2   Harry Potter and the Order of the Phoenix (Har...    29221        4.49
# 3          The Two Towers (The Lord of the Rings  #2)     5798        4.44
# 4   Harry Potter and the Chamber of Secrets (Harry...    34692        4.42
# 5      A Clash of Kings  (A Song of Ice and Fire  #2)    16535        4.41
# 6                                      The Book Thief    86881        4.37
# 7   The Fellowship of the Ring (The Lord of the Ri...    13670        4.36
# 8                            Man's Search for Meaning    13449        4.36
# 9                                           The Lorax     3532        4.35
# 10                               A Light in the Attic     2567        4.34
# 11                                            Matilda    11576        4.31
#
#     RatingsCount
# 0        2095690
# 1        2339585
# 2        2153167
# 3         593467
# 4        2293963
# 5         638766
# 6        1516367
# 7        2128944
# 8         282127
# 9         260054
# 10        349247
# 11        541914

# %%
#goodreads books with a rating >=4.3 and highest counts of Reviews  (sort by UserRating)
df_test2 = df_goodreads[
    (df_goodreads['Reviews'] > 10000) & (df_goodreads['UserRating'] >= 4.3)
     ][['Name', 'Reviews','UserRating','RatingsCount']].sort_values(
        by='UserRating',ascending=False
     ).drop_duplicates().reset_index(drop=True).head(25)
df_test2

#gr_topReviewCounts = df_goodreads[df_goodreads['Reviews'] > 35000][['Name', 'Reviews','UserRating','RatingsCount']].sort_values(by='Reviews',ascending=False).drop_duplicates().reset_index(drop=True).head(25)
#gr_topReviewCounts
# Out:
#                                                 Name  Reviews  UserRating  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...    27591        4.57
# 1  Harry Potter and the Prisoner of Azkaban (Harr...    36325        4.56
# 2  Harry Potter and the Order of the Phoenix (Har...    29221        4.49
# 3  Harry Potter and the Chamber of Secrets (Harry...    34692        4.42
# 4     A Clash of Kings  (A Song of Ice and Fire  #2)    16535        4.41
# 5                                     The Book Thief    86881        4.37
# 6  The Fellowship of the Ring (The Lord of the Ri...    13670        4.36
# 7                           Man's Search for Meaning    13449        4.36
# 8                 Dragonfly in Amber (Outlander  #2)    11121        4.32
# 9                                            Matilda    11576        4.31
#
#    RatingsCount
# 0       2095690
# 1       2339585
# 2       2153167
# 3       2293963
# 4        638766
# 5       1516367
# 6       2128944
# 7        282127
# 8        222140
# 9        541914

# %%
# Compute the correlation matrix (to explore further at a later time: number of page influence on ratings?)
# helped by chatGPT
dropCol_corr = ['Name','Author']
df_goodreads_corr = df_goodreads.drop(columns=dropCol_corr)
df_goodreads_corr
corr_matrix = df_goodreads_corr.corr()

# Create a seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Create a basic pair plot (for future exploration of relations between pages and costs)
sns.pairplot(df_goodreads[['Reviews', 'UserRating', 'RatingsCount', 'Pages']])
plt.show()
# Out:
# /Users/darpino/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
